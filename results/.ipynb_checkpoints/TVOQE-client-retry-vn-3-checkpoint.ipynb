# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import math
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#train_df = pd.read_csv("Apr-04-2021.csv", index_col=0)
train_df = pd.read_csv("client-retry-vn-3.csv")
train_df.head()
# Out:
#    Run Implementation    Mode                               TestName  Status  \
# 0    0          quant  client  quic_client_test_version_negociation0     NaN
# 1    1          quant  client                quic_client_test_retry0     NaN
# 2    2          quant  client  quic_client_test_version_negociation0     NaN
# 3    3          quant  client                quic_client_test_retry0     NaN
# 4    4          quant  client                quic_client_test_retry0     NaN
#
#                                             ErrorIEV  \
# 0                                                  +
# 1  ivy_return_code(1)+assumption_failed("/usr/loc...
# 2  ivy_return_code(1)+assumption_failed("/usr/loc...
# 3  ivy_return_code(1)+assumption_failed("/usr/loc...
# 4                                                NaN
#
#                                           OutputFile  NbPktSend  isPass
# 0  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 1  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 2  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 3  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 4  /home/user/Documents/QUIC-FormalVerification/r...        0.0     1.0

# %%
train_df = train_df[train_df.Mode != 'server']

# %%
server_name = train_df.Implementation.unique()
servers = []
print(server_name)
servers = []
for i, row in train_df.iterrows():
    resultFile = row["OutputFile"][len("/home/user/Documents/QUIC-FormalVerification/results/"):]
    splited = resultFile.split("/")
    resultFile = splited[0] +"/"+ splited[1] + "/res_client.txt"
    #print(resultFile)
    if os.path.isfile(resultFile): 
        f = open(resultFile, "r", encoding="ISO-8859-1")
        s = f.read()
        #print(s)
        if "cargo run --manifest-path=tools/apps/Cargo.toml" in s:
            train_df.loc[i, "Implementation"] = "quiche"
        elif "cargo run" in s:
            train_df.loc[i, "Implementation"] = "quinn"
        elif "./http_server" in s:
            train_df.loc[i, "Implementation"] = "lsquic"
        elif "./picoquicdemo" in s:
            train_df.loc[i, "Implementation"] = "picoquic"
        elif "./server -d" in s:
            train_df.loc[i, "Implementation"] = "quant"
        elif "./server -c" in s:
            train_df.loc[i, "Implementation"] = "quic-go"
        elif "python3 examples/" in s:
            train_df.loc[i, "Implementation"] = "aioquic"
        elif "echo" in s:
            train_df.loc[i, "Implementation"] = "mvfst"
        
#print(servers)
print(train_df.Implementation.unique())
train_df["isPass"] = train_df["isPass"].replace(0.0, 0)
train_df["isPass"] = train_df["isPass"].replace(1.0, 1)

for i, row in train_df.iterrows():
    if isinstance(row["TestName"], str):
        train_df.loc[i, "TestName"] = row["TestName"].replace("0","")
    else:
        index = row["OutputFile"].find("q")
        train_df.loc[i, "TestName"] = row["OutputFile"][index:].replace("0","").replace(".iev","")

train_df.head()
# Out:
# ['quant' 'picoquic']
# ['aioquic' 'quant' 'picoquic' 'quiche' 'quinn' 'mvfst']
#    Run Implementation    Mode                              TestName  Status  \
# 0    0        aioquic  client  quic_client_test_version_negociation     NaN
# 1    1          quant  client                quic_client_test_retry     NaN
# 2    2          quant  client  quic_client_test_version_negociation     NaN
# 3    3          quant  client                quic_client_test_retry     NaN
# 4    4          quant  client                quic_client_test_retry     NaN
#
#                                             ErrorIEV  \
# 0                                                  +
# 1  ivy_return_code(1)+assumption_failed("/usr/loc...
# 2  ivy_return_code(1)+assumption_failed("/usr/loc...
# 3  ivy_return_code(1)+assumption_failed("/usr/loc...
# 4                                                NaN
#
#                                           OutputFile  NbPktSend  isPass
# 0  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 1  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 2  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 3  /home/user/Documents/QUIC-FormalVerification/r...        0.0     0.0
# 4  /home/user/Documents/QUIC-FormalVerification/r...        0.0     1.0

# %%
for i, row in train_df.iterrows():
    if row["isPass"] == 0.0:
        resultFile = "client-result" + row["OutputFile"][8:]
        f = open(resultFile, "r")
        content = f.read()
        if "frame.connection_close:" in content and not "quic_client_test_connection_close" in resultFile:
            start_index = content.find("frame.connection_close:")
            end_index = content.find(",",start_index)
            train_df.loc[i, "ErrorIEV"] = content[start_index:end_index+1].replace(",","") + "}"
        elif "Run out of cid" in content:
            train_df.loc[i, "ErrorIEV"] = "Run out of cid"
        elif "timeout+binding id:" in content :
            train_df.loc[i, "ErrorIEV"] = "Timeout"
        elif "ivy_return_code(134)" in content :
            train_df.loc[i, "ErrorIEV"] = "Segmentation Fault 134"
        elif "ivy_return_code(134)" in content :
            train_df.loc[i, "ErrorIEV"] = "Segmentation Fault 134"
        elif content.count("tls_recv_event") > 10:
            train_df.loc[i, "ErrorIEV"] = "Handshake not completed"
        elif "timeout" in content and "undecryptable_packet_event" in content:
            train_df.loc[i, "ErrorIEV"] = "Handshake not completed" 
        elif "ivy_return_code(1)+value(" in row["ErrorIEV"]:
            train_df.loc[i, "ErrorIEV"] = "Run out of cid"
        elif 'ivy_return_code(1)+"")' in row["ErrorIEV"]:
            start_index = content.find('assumption_failed(""')
            end_index = content.find('"")',start_index)
            c = content[start_index:end_index+1]
            c = c.replace('assumption_failed(""',"")
            train_df.loc[i, "ErrorIEV"] = c
        elif "timeout+binding id:" in row["ErrorIEV"] :
            train_df.loc[i, "ErrorIEV"] = "Timeout binding ID"
        elif "timeout+sending id:" in row["ErrorIEV"] :
            train_df.loc[i, "ErrorIEV"] = "Timeout sending ID"
    else:
        train_df.loc[i, "ErrorIEV"] = "No Error"
        
for i, row in train_df.iterrows():
    if row["isPass"] == 0.0:
        train_df.loc[i, "ErrorIEV"]  = train_df.loc[i, "ErrorIEV"].replace("\n","").replace("    ","")

# %%
train_df.TestName.unique()
# Out:
# array(['quic_client_test_max', 'quic_client_test_tp_error',
#        'quic_client_test_double_tp_error',
#        'quic_client_test_tp_acticoid_error',
#        'quic_client_test_tp_limit_acticoid_error',
#        'quic_client_test_retirecoid_error',
#        'quic_client_test_newcoid_zero_error',
#        'quic_client_test_accept_maxdata',
#        'quic_client_test_tp_prefadd_error', 'quic_client_test_no_odci',
#        'quic_client_test_ext_min_ack_delay',
#        'quic_client_test_token_error'], dtype=object)

# %%
train_df["ErrorIEV"].unique().tolist()
# Out:
# ['No Error',
#  'server_return_code(1)+timeout',
#  'Handshake not completed',
#  'Timeout',
#  'Timeout sending ID',
#  'frame.connection_close:{err_code:0x8}',
#  'Segmentation Fault 139',
#  'frame.connection_close:{err_code:0x130}',
#  'require is_connection_id_limit_error;"',
#  ' require pkt.payload = queued_frames(scid);"',
#  'frame.connection_close:{err_code:0xa}',
#  'require is_protocol_violation;"',
#  'frame.connection_close:{err_code:0x4}',
#  'frame.connection_close:{err_code:0x5}',
#  'require conn_total_data(the_cid) > 0;"',
#  'require stream_id_allowed(dcid,f.id);  # [6]"',
#  '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"',
#  'require connected(dcid) & connected_to(dcid) = scid;"',
#  'require ~_generating & ~queued_non_ack(scid) -> ack_credit(scid) > 0;  # [5]"',
#  'Segmentation Fault 134']

# %%
from scapy.all import *
import threading
import multiprocessing

# splitting dataframe by row index 
total_rows = train_df.shape[0]
print(total_rows)
cnt  = 10 #multiprocessing.cpu_count()
size = total_rows / cnt
size = int(size)
print(size)
list_of_dfs = [train_df.loc[i:i+size-1,:] for i in range(0, len(train_df),size)]
print(len(list_of_dfs))
print()
j = 0


def process_pkt(df):
    for index, row in df.iterrows():
        outfile = row["OutputFile"]
        if "iev" in row["OutputFile"] :
            i =  row["OutputFile"][outfile.find("/",13)+1:outfile.find("/",14)] 
            if isinstance(row["TestName"],str) and not row["TestName"] == np.nan :
                resultFile = "client-result/temp/" + str(i) + "_quic_client_" + str(row["TestName"])  + ".pcap"
                packets = rdpcap(resultFile)
                ln = len(packets)
                df.loc[index, "NbPktSend"] = ln
    
        
for index in range(cnt):
    process_pkt(list_of_dfs[index])
    toPrint = (j/size) * 10
    print(str(toPrint) + "% Processed")
    train_df.to_csv(path_or_buf="client_processed.csv",index=False)
    j += size
    

train_df.head()
# Out:
# 5553
# 555
# 11
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 0.0% Processed
# 10.0% Processed
# 20.0% Processed
# 30.0% Processed
# 40.0% Processed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\scapy\utils.py in open(filename)
#     999             try:
# -> 1000                 fdesc = gzip.open(filename, "rb")
#    1001                 magic = fdesc.read(4)
#
# C:\ProgramData\Anaconda3\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      52     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#
# C:\ProgramData\Anaconda3\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     162         if fileobj is None:
# --> 163             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     164         if filename is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'client-result/temp/5_quic_client_quic_client_test_token_error.pcap'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-7df7c89907a0> in <module>
#      29
#      30 for index in range(cnt):
# ---> 31     process_pkt(list_of_dfs[index])
#      32     toPrint = (j/size) * 10
#      33     print(str(toPrint) + "% Processed")
#
# <ipython-input-10-7df7c89907a0> in process_pkt(df)
#      23             if isinstance(row["TestName"],str) and not row["TestName"] == np.nan :
#      24                 resultFile = "client-result/temp/" + str(i) + "_quic_client_" + str(row["TestName"])  + ".pcap"
# ---> 25                 packets = rdpcap(resultFile)
#      26                 ln = len(packets)
#      27                 df.loc[index, "NbPktSend"] = ln
#
# C:\ProgramData\Anaconda3\lib\site-packages\scapy\utils.py in rdpcap(filename, count)
#     948     :param count: read only <count> packets
#     949     """
# --> 950     with PcapReader(filename) as fdesc:
#     951         return fdesc.read_all(count=count)
#     952
#
# C:\ProgramData\Anaconda3\lib\site-packages\scapy\utils.py in __call__(cls, filename)
#     971         """
#     972         i = cls.__new__(cls, cls.__name__, cls.__bases__, cls.__dict__)
# --> 973         filename, fdesc, magic = cls.open(filename)
#     974         if not magic:
#     975             raise Scapy_Exception(
#
# C:\ProgramData\Anaconda3\lib\site-packages\scapy\utils.py in open(filename)
#    1001                 magic = fdesc.read(4)
#    1002             except IOError:
# -> 1003                 fdesc = open(filename, "rb")
#    1004                 magic = fdesc.read(4)
#    1005         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'client-result/temp/5_quic_client_quic_client_test_token_error.pcap'

# %%
tests = train_df.TestName.unique()
for t in tests:
    subdf = train_df.loc[train_df['TestName'] == t]
    #subdf = subdf.loc[subdf['Implementation'] != "quinn"]
    max_value = subdf["NbPktSend"].max() 
    
    plt.hist(subdf['NbPktSend'], color = 'blue', edgecolor = 'black',
             range = [0,max_value],bins=max(int(max_value),1))

    # seaborn histogram
    sns.displot(subdf['NbPktSend'],
                 kde=True)
    # Add labels
    plt.xticks(np.arange(0, int(max_value),5))
    # positions = (0, 1)
    # labels = ("Fail", "Pass")
    # plt.xticks(positions, labels)
    plt.title("Packets send for test " + t)
    plt.xlabel('Number of packet')
    plt.ylabel('%')
    filename = 'plot/' + "packets_" + t + '.png'
    plt.savefig(filename)
    plt.show()
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
for t in tests:
    subdf = train_df.loc[train_df['TestName'] == t]
    plt.hist(subdf['isPass'], color = 'blue', edgecolor = 'black')

    # seaborn histogram
    sns.displot(subdf['isPass'], kde=False)
    # Add labels
    plt.title(t)
    plt.xticks(np.arange(0, 2, 1))
    positions = (0, 1)
    labels = ("Fail", "Pass")
    plt.xticks(positions, labels)
    plt.xlabel('isPass')
    plt.ylabel('Average Accuracy')
    plt.show()

# %%
tests = train_df.TestName.unique()

servers = ['lsquic', 'quinn',  'mvfst', 'picoquic', 'quant', 'quic-go', 'aioquic']
#plt.figure(figsize=[10,10]) 'lsquic',
#f,a = plt.subplots(2,2)
#a = a.ravel()

for t in tests:
    subdf = train_df.loc[train_df['TestName'] == t]
    for s in servers:
        subsubdf = subdf.loc[subdf['Implementation'] == s]
        plt.hist(subsubdf['isPass'], color = 'blue', edgecolor = 'black')

        # seaborn histogram
        sns.displot(subsubdf['isPass'], kde=False)
        # Add labels
        plt.xticks(np.arange(0, 1, 1))
        positions = (0, 1)
        labels = ("Fail", "Pass")
        plt.xticks(positions, labels)
        plt.title(t + " for " + s)
        plt.xlabel('isPass')
        plt.ylabel('%')
        filename = 'plot/' + t + "_for_" + s + '.png'
        plt.savefig(filename)

        plt.show()

# %%
for t in servers:
    subdf = train_df.loc[train_df['Implementation'] == t]
    
    print(t)
    print(len(subdf.index))
    print(subdf["isPass"].sum())
    print()
# Out:
# lsquic
# 1100
# 0.0
#
# quinn
# 0
# 0.0
#
# mvfst
# 1100
# 0.0
#
# picoquic
# 1100
# 40.0
#
# quant
# 0
# 0.0
#
# quic-go
# 1153
# 1.0
#
# aioquic
# 1100
# 89.0

# %%
for t in servers:
    subdf = train_df.loc[train_df['Implementation'] == t]
    for s in tests:
        ssubdf = subdf.loc[subdf['TestName'] == s]
        print(t)
        print(s)
        print(len(ssubdf.index))
        print(ssubdf["isPass"].sum())
        print()
# Out:
# lsquic
# quic_client_test_max
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_error
# 100
# 0.0
#
# lsquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# lsquic
# quic_client_test_accept_maxdata
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# lsquic
# quic_client_test_no_odci
# 100
# 0.0
#
# lsquic
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# lsquic
# quic_client_test_token_error
# 0
# 0.0
#
# quinn
# quic_client_test_max
# 0
# 0.0
#
# quinn
# quic_client_test_tp_error
# 0
# 0.0
#
# quinn
# quic_client_test_double_tp_error
# 0
# 0.0
#
# quinn
# quic_client_test_tp_acticoid_error
# 0
# 0.0
#
# quinn
# quic_client_test_tp_limit_acticoid_error
# 0
# 0.0
#
# quinn
# quic_client_test_retirecoid_error
# 0
# 0.0
#
# quinn
# quic_client_test_newcoid_zero_error
# 0
# 0.0
#
# quinn
# quic_client_test_accept_maxdata
# 0
# 0.0
#
# quinn
# quic_client_test_tp_prefadd_error
# 0
# 0.0
#
# quinn
# quic_client_test_no_odci
# 0
# 0.0
#
# quinn
# quic_client_test_ext_min_ack_delay
# 0
# 0.0
#
# quinn
# quic_client_test_token_error
# 0
# 0.0
#
# mvfst
# quic_client_test_max
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_error
# 100
# 0.0
#
# mvfst
# quic_client_test_double_tp_error
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# mvfst
# quic_client_test_accept_maxdata
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# mvfst
# quic_client_test_no_odci
# 100
# 0.0
#
# mvfst
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# mvfst
# quic_client_test_token_error
# 0
# 0.0
#
# picoquic
# quic_client_test_max
# 100
# 38.0
#
# picoquic
# quic_client_test_tp_error
# 100
# 0.0
#
# picoquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# picoquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# picoquic
# quic_client_test_accept_maxdata
# 100
# 1.0
#
# picoquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# picoquic
# quic_client_test_no_odci
# 100
# 0.0
#
# picoquic
# quic_client_test_ext_min_ack_delay
# 100
# 1.0
#
# picoquic
# quic_client_test_token_error
# 0
# 0.0
#
# quant
# quic_client_test_max
# 0
# 0.0
#
# quant
# quic_client_test_tp_error
# 0
# 0.0
#
# quant
# quic_client_test_double_tp_error
# 0
# 0.0
#
# quant
# quic_client_test_tp_acticoid_error
# 0
# 0.0
#
# quant
# quic_client_test_tp_limit_acticoid_error
# 0
# 0.0
#
# quant
# quic_client_test_retirecoid_error
# 0
# 0.0
#
# quant
# quic_client_test_newcoid_zero_error
# 0
# 0.0
#
# quant
# quic_client_test_accept_maxdata
# 0
# 0.0
#
# quant
# quic_client_test_tp_prefadd_error
# 0
# 0.0
#
# quant
# quic_client_test_no_odci
# 0
# 0.0
#
# quant
# quic_client_test_ext_min_ack_delay
# 0
# 0.0
#
# quant
# quic_client_test_token_error
# 0
# 0.0
#
# quic-go
# quic_client_test_max
# 100
# 0.0
#
# quic-go
# quic_client_test_tp_error
# 105
# 0.0
#
# quic-go
# quic_client_test_double_tp_error
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_acticoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_limit_acticoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_retirecoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_newcoid_zero_error
# 105
# 0.0
#
# quic-go
# quic_client_test_accept_maxdata
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_prefadd_error
# 105
# 0.0
#
# quic-go
# quic_client_test_no_odci
# 105
# 0.0
#
# quic-go
# quic_client_test_ext_min_ack_delay
# 105
# 0.0
#
# quic-go
# quic_client_test_token_error
# 3
# 1.0
#
# aioquic
# quic_client_test_max
# 100
# 85.0
#
# aioquic
# quic_client_test_tp_error
# 100
# 0.0
#
# aioquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# aioquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# aioquic
# quic_client_test_accept_maxdata
# 100
# 4.0
#
# aioquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# aioquic
# quic_client_test_no_odci
# 100
# 0.0
#
# aioquic
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# aioquic
# quic_client_test_token_error
# 0
# 0.0

# %%
all_errors = train_df["ErrorIEV"].unique().tolist()
res = []
for i, row in train_df.iterrows():
    ind = all_errors.index(row["ErrorIEV"])
    res.append(ind)
train_df["ErrorsCode"] = res


for s in servers:
    subdf = train_df.loc[train_df['Implementation'] == s]
    for t in tests:
        subsubdf = subdf.loc[subdf['TestName'] == t]
        errors = subsubdf["ErrorIEV"].unique()
        
        all_errors = subsubdf["ErrorIEV"].unique().tolist()
        res = []
        for i, row in subsubdf.iterrows():
            ind = all_errors.index(row["ErrorIEV"])
            res.append(ind)
        subsubdf["ErrorsCode"] = res
        
        print(t)
        print(s)
        print(all_errors)
        
                
        # seaborn histogram
        sns.displot(x=subsubdf['ErrorsCode'],  kde=False ) #,hue="Implementation"
        # Add labels
        plt.title("Errors for " + s + " in test " + t)
        plt.xticks(np.arange(0,len(all_errors)), rotation=90)  #'vertical'
        positions = tuple(np.arange(0, len(all_errors)))
        labels =  tuple(errors.tolist())
        plt.xticks(positions, labels)
        plt.xlabel('Errors')
        plt.ylabel('Count')
        filename = 'plot/' + "errors_for_" + s + "_in_test_" + t + '.png'
        fig = plt.gcf()
        plt.tight_layout()
        #fig.set_size_inches(20,20)
        plt.savefig(filename, dpi=fig.dpi*2)
        plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_max
# lsquic
# ['require conn_total_data(the_cid) > 0;"', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_error
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_double_tp_error
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_acticoid_error
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_limit_acticoid_error
# lsquic
# ['require is_connection_id_limit_error;"', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_retirecoid_error
# lsquic
# ['require is_protocol_violation;"', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_newcoid_zero_error
# lsquic
# ['Handshake not completed', 'require is_protocol_violation;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_accept_maxdata
# lsquic
# ['Handshake not completed', 'require conn_total_data(the_cid) > 0;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_prefadd_error
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_no_odci
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_ext_min_ack_delay
# lsquic
# ['Timeout sending ID', 'Handshake not completed']
# quic_client_test_token_error
# lsquic
# []
# quic_client_test_max
# quinn
# []
# quic_client_test_tp_error
# quinn
# []
# quic_client_test_double_tp_error
# quinn
# []
# quic_client_test_tp_acticoid_error
# quinn
# []
# quic_client_test_tp_limit_acticoid_error
# quinn
# []
# quic_client_test_retirecoid_error
# quinn
# []
# quic_client_test_newcoid_zero_error
# quinn
# []
# quic_client_test_accept_maxdata
# quinn
# []
# quic_client_test_tp_prefadd_error
# quinn
# []
# quic_client_test_no_odci
# quinn
# []
# quic_client_test_ext_min_ack_delay
# quinn
# []
# quic_client_test_token_error
# quinn
# []
# quic_client_test_max
# mvfst
# ['Handshake not completed', 'Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_double_tp_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_acticoid_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_limit_acticoid_error
# mvfst
# ['Timeout', 'Handshake not completed']
# quic_client_test_retirecoid_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_newcoid_zero_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_accept_maxdata
# mvfst
# ['Timeout']
# quic_client_test_tp_prefadd_error
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_no_odci
# mvfst
# ['Timeout']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_ext_min_ack_delay
# mvfst
# ['Timeout', 'Handshake not completed']
# quic_client_test_token_error
# mvfst
# []
# quic_client_test_max
# picoquic
# ['No Error', 'frame.connection_close:{err_code:0x4}', 'require stream_id_allowed(dcid,f.id);  # [6]"', 'require connected(dcid) & connected_to(dcid) = scid;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_error
# picoquic
# ['Timeout sending ID', 'require connected(dcid) & connected_to(dcid) = scid;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_double_tp_error
# picoquic
# ['frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_acticoid_error
# picoquic
# ['Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_limit_acticoid_error
# picoquic
# [' require pkt.payload = queued_frames(scid);"', 'frame.connection_close:{err_code:0xa}', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_retirecoid_error
# picoquic
# [' require pkt.payload = queued_frames(scid);"', 'require connected(dcid) & connected_to(dcid) = scid;"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_newcoid_zero_error
# picoquic
# [' require pkt.payload = queued_frames(scid);"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"', 'require is_protocol_violation;"', 'require connected(dcid) & connected_to(dcid) = scid;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_accept_maxdata
# picoquic
# ['frame.connection_close:{err_code:0x4}', 'require connected(dcid) & connected_to(dcid) = scid;"', 'No Error']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_prefadd_error
# picoquic
# ['frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_no_odci
# picoquic
# ['frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_ext_min_ack_delay
# picoquic
# ['Timeout sending ID', 'require connected(dcid) & connected_to(dcid) = scid;"', 'No Error']
# quic_client_test_token_error
# picoquic
# []
# quic_client_test_max
# quant
# []
# quic_client_test_tp_error
# quant
# []
# quic_client_test_double_tp_error
# quant
# []
# quic_client_test_tp_acticoid_error
# quant
# []
# quic_client_test_tp_limit_acticoid_error
# quant
# []
# quic_client_test_retirecoid_error
# quant
# []
# quic_client_test_newcoid_zero_error
# quant
# []
# quic_client_test_accept_maxdata
# quant
# []
# quic_client_test_tp_prefadd_error
# quant
# []
# quic_client_test_no_odci
# quant
# []
# quic_client_test_ext_min_ack_delay
# quant
# []
# quic_client_test_token_error
# quant
# []
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_max
# quic-go
# ['frame.connection_close:{err_code:0x130}', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_error
# quic-go
# ['server_return_code(1)+timeout', 'Handshake not completed', 'Timeout', 'Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_double_tp_error
# quic-go
# ['Handshake not completed', 'server_return_code(1)+timeout', 'Timeout', 'Timeout sending ID', 'frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_acticoid_error
# quic-go
# ['Handshake not completed', 'frame.connection_close:{err_code:0x8}', 'Timeout', 'Timeout sending ID', 'Segmentation Fault 139']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_limit_acticoid_error
# quic-go
# ['frame.connection_close:{err_code:0x130}', 'Handshake not completed', 'Timeout', 'require is_connection_id_limit_error;"', ' require pkt.payload = queued_frames(scid);"', 'Segmentation Fault 134']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_retirecoid_error
# quic-go
# ['frame.connection_close:{err_code:0x130}', 'Handshake not completed', 'Timeout', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"', ' require pkt.payload = queued_frames(scid);"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_newcoid_zero_error
# quic-go
# ['Handshake not completed', 'frame.connection_close:{err_code:0x130}', 'Timeout', ' require pkt.payload = queued_frames(scid);"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_accept_maxdata
# quic-go
# ['Handshake not completed', 'frame.connection_close:{err_code:0x130}', 'Timeout', 'frame.connection_close:{err_code:0x4}', 'frame.connection_close:{err_code:0x5}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_prefadd_error
# quic-go
# ['frame.connection_close:{err_code:0x130}', 'Handshake not completed', 'Timeout', 'Timeout sending ID', 'frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# quic_client_test_no_odci
# quic-go
# ['Handshake not completed', 'server_return_code(1)+timeout', 'Segmentation Fault 139', 'require ~_generating & ~queued_non_ack(scid) -> ack_credit(scid) > 0;  # [5]"', 'Timeout', 'Timeout sending ID', 'frame.connection_close:{err_code:0x8}']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# quic_client_test_ext_min_ack_delay
# quic-go
# ['frame.connection_close:{err_code:0x130}', 'Handshake not completed', 'Timeout', 'Timeout sending ID', 'require ~_generating & ~queued_non_ack(scid) -> ack_credit(scid) > 0;  # [5]"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_token_error
# quic-go
# ['No Error', 'Handshake not completed']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# quic_client_test_max
# aioquic
# ['No Error', 'frame.connection_close:{err_code:0x5}', 'require ~_generating & ~queued_non_ack(scid) -> ack_credit(scid) > 0;  # [5]"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_error
# aioquic
# ['Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_double_tp_error
# aioquic
# ['Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_acticoid_error
# aioquic
# ['Segmentation Fault 139']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_tp_limit_acticoid_error
# aioquic
# [' require pkt.payload = queued_frames(scid);"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_retirecoid_error
# aioquic
# [' require pkt.payload = queued_frames(scid);"', 'require is_protocol_violation;"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# quic_client_test_newcoid_zero_error
# aioquic
# [' require pkt.payload = queued_frames(scid);"', '\trequire num_queued_frames(scid) > 0 -> e = queued_level(scid);"', 'require is_protocol_violation;"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# quic_client_test_accept_maxdata
# aioquic
# ['frame.connection_close:{err_code:0x5}', 'No Error', 'require ~_generating & ~queued_non_ack(scid) -> ack_credit(scid) > 0;  # [5]"']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_tp_prefadd_error
# aioquic
# ['Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_no_odci
# aioquic
# ['Segmentation Fault 139']
# quic_client_test_ext_min_ack_delay
# aioquic
# ['Timeout sending ID']
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# quic_client_test_token_error
# aioquic
# []

# %%
for i, row in train_df.iterrows():
    resultFile = "client-result" + row["OutputFile"][8:]
    f = open(resultFile, "r")
    content = f.read()
    if "TEST_SCIL " in content:
        start_index = content.find("TEST_SCIL ")
        end_index = content.find("\n",start_index)
        scil = int(content[start_index+len("TEST_DCIL "):end_index+1].replace("\n","")) 
        if scil > 16:
            train_df.drop(train_df.index,axis=0)
    if "TEST_DCIL " in content:
        start_index = content.find("TEST_DCIL ")
        end_index = content.find("\n",start_index)
        dcil = int(content[start_index+len("TEST_DCIL "):end_index+1].replace("\n","")) 
        if dcil > 16:
            train_df.drop(train_df.index,axis=0)

train_df.to_csv(path_or_buf="client_processed_cid.csv",index=False)

train_df.head()

# %%
tests = train_df.TestName.unique()
servers = train_df.Implementation.unique()
for t in servers:
    subdf = train_df.loc[train_df['Implementation'] == t]
    
    print(t)
    print(len(subdf.index))
    print(subdf["isPass"].sum())
    print()
# Out:
# picoquic
# 1100
# 40.0
#
# aioquic
# 1100
# 89.0
#
# quic-go
# 1153
# 1.0
#
# mvfst
# 1100
# 0.0
#
# lsquic
# 1100
# 0.0

# %%
for t in servers:
    subdf = train_df.loc[train_df['Implementation'] == t]
    for s in tests:
        ssubdf = subdf.loc[subdf['TestName'] == s]
        print(t)
        print(s)
        print(len(ssubdf.index))
        print(ssubdf["isPass"].sum())
        print()
# Out:
# picoquic
# quic_client_test_max
# 100
# 38.0
#
# picoquic
# quic_client_test_tp_error
# 100
# 0.0
#
# picoquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# picoquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# picoquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# picoquic
# quic_client_test_accept_maxdata
# 100
# 1.0
#
# picoquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# picoquic
# quic_client_test_no_odci
# 100
# 0.0
#
# picoquic
# quic_client_test_ext_min_ack_delay
# 100
# 1.0
#
# picoquic
# quic_client_test_token_error
# 0
# 0.0
#
# aioquic
# quic_client_test_max
# 100
# 85.0
#
# aioquic
# quic_client_test_tp_error
# 100
# 0.0
#
# aioquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# aioquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# aioquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# aioquic
# quic_client_test_accept_maxdata
# 100
# 4.0
#
# aioquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# aioquic
# quic_client_test_no_odci
# 100
# 0.0
#
# aioquic
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# aioquic
# quic_client_test_token_error
# 0
# 0.0
#
# quic-go
# quic_client_test_max
# 100
# 0.0
#
# quic-go
# quic_client_test_tp_error
# 105
# 0.0
#
# quic-go
# quic_client_test_double_tp_error
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_acticoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_limit_acticoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_retirecoid_error
# 105
# 0.0
#
# quic-go
# quic_client_test_newcoid_zero_error
# 105
# 0.0
#
# quic-go
# quic_client_test_accept_maxdata
# 105
# 0.0
#
# quic-go
# quic_client_test_tp_prefadd_error
# 105
# 0.0
#
# quic-go
# quic_client_test_no_odci
# 105
# 0.0
#
# quic-go
# quic_client_test_ext_min_ack_delay
# 105
# 0.0
#
# quic-go
# quic_client_test_token_error
# 3
# 1.0
#
# mvfst
# quic_client_test_max
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_error
# 100
# 0.0
#
# mvfst
# quic_client_test_double_tp_error
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# mvfst
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# mvfst
# quic_client_test_accept_maxdata
# 100
# 0.0
#
# mvfst
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# mvfst
# quic_client_test_no_odci
# 100
# 0.0
#
# mvfst
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# mvfst
# quic_client_test_token_error
# 0
# 0.0
#
# lsquic
# quic_client_test_max
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_error
# 100
# 0.0
#
# lsquic
# quic_client_test_double_tp_error
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_acticoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_limit_acticoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_retirecoid_error
# 100
# 0.0
#
# lsquic
# quic_client_test_newcoid_zero_error
# 100
# 0.0
#
# lsquic
# quic_client_test_accept_maxdata
# 100
# 0.0
#
# lsquic
# quic_client_test_tp_prefadd_error
# 100
# 0.0
#
# lsquic
# quic_client_test_no_odci
# 100
# 0.0
#
# lsquic
# quic_client_test_ext_min_ack_delay
# 100
# 0.0
#
# lsquic
# quic_client_test_token_error
# 0
# 0.0
